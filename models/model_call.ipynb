# %%
# Python Code version
# Import Dependencies
import pandas as pd
import tensorflow as tf
from tensorflow import keras


def run_model(bath, bed, sqft, zip):
    
    # Import necessary files
    census_df = pd.read_csv("../Resources/acs5_2018.csv")
    model = tf.keras.models.load_model("housing_model.h5")
    model = tf.keras.models.load_model("housing_model.h5")
    mean = pd.read_csv("mean_norm.csv")
    std = pd.read_csv("std_norm.csv")

    input_df =pd.DataFrame({"bathroom_ct": [bath],
                       "bedroom_ct": [bed],
                       "home_sqft": [sqft],
                       "zipcode": [zip]})
    merged_df = input_df.merge(census_df, how="inner")
    merged_df.drop("zipcode", axis=1, inplace=True)

    norm_df = (merged_df - mean) / std
    return(model.predict(norm_df)[0][0])

run_model(2,3,1666,85003)
# Out:
# 391602.38

# %%
# Import Dependencies
import pandas as pd
import tensorflow as tf
from tensorflow import keras

# %%
# Import relevant files
census_df = pd.read_csv("../Resources/acs5_2018.csv")
census_df
# Out:
#        zipcode  Population  Median Age  Household Income  Per Capita Income  \
# 0        601.0     17242.0        40.5           13092.0             6999.0
# 1        602.0     38442.0        42.3           16358.0             9277.0
# 2        603.0     48814.0        41.1           16603.0            11307.0
# 3        606.0      6437.0        43.3           12832.0             5943.0
# 4        610.0     27073.0        42.1           19309.0            10220.0
# ...        ...         ...         ...               ...                ...
# 30883  99921.0      1986.0        41.4           58571.0            34414.0
# 30884  99922.0       330.0        39.5           34028.0            18213.0
# 30885  99925.0       927.0        43.6           57375.0            25840.0
# 30886  99926.0      1635.0        34.5           53409.0            22453.0
# 30887  99929.0      2484.0        49.5           57583.0            31489.0
#
#        Poverty Rate  Population 25 and Over  \
# 0          0.624754                 11838.0
# 1          0.510145                 27411.0
# 2          0.498566                 34274.0
# 3          0.646730                  4516.0
# 4          0.433051                 19164.0
# ...             ...                     ...
# 30883      0.144008                  1397.0
# 30884      0.390909                   204.0
# 30885      0.185545                   643.0
# 30886      0.143731                  1019.0
# 30887      0.077295                  1875.0
#
#        Rate 25 and Over w/ less than 1st grade  \
# 0                                     0.043166
# 1                                     0.034256
# 2                                     0.028389
# 3                                     0.040965
# 4                                     0.033552
# ...                                        ...
# 30883                                 0.000000
# 30884                                 0.000000
# 30885                                 0.000000
# 30886                                 0.000000
# 30887                                 0.001067
#
#        Rate 25 and Over w/ Some or Completed Elementary School  \
# 0                                               0.143183
# 1                                               0.142571
# 2                                               0.102468
# 3                                               0.185562
# 4                                               0.139063
# ...                                                  ...
# 30883                                           0.002147
# 30884                                           0.000000
# 30885                                           0.000000
# 30886                                           0.000981
# 30887                                           0.006933
#
#        Rate 25 and Over w/ Some or Completed Middle School  \
# 0                                               0.057696
# 1                                               0.059064
# 2                                               0.049775
# 3                                               0.087024
# 4                                               0.040753
# ...                                                  ...
# 30883                                           0.005727
# 30884                                           0.019608
# 30885                                           0.004666
# 30886                                           0.018646
# 30887                                           0.024533
#
#        Rate 25 and Over w/ Some High School  \
# 0                                  0.115138
# 1                                  0.103061
# 2                                  0.103548
# 3                                  0.168733
# 4                                  0.096066
# ...                                     ...
# 30883                              0.087330
# 30884                              0.068627
# 30885                              0.093313
# 30886                              0.075564
# 30887                              0.084267
#
#        Rate 25 and Over w/ Completed High School or Equivalent  \
# 0                                               0.255786
# 1                                               0.244354
# 2                                               0.284210
# 3                                               0.314880
# 4                                               0.290597
# ...                                                  ...
# 30883                                           0.353615
# 30884                                           0.455882
# 30885                                           0.454121
# 30886                                           0.369971
# 30887                                           0.376000
#
#        Rate 25 and Over w/ Some college, less than 1 year  \
# 0                                               0.017064
# 1                                               0.013243
# 2                                               0.017156
# 3                                               0.001993
# 4                                               0.012628
# ...                                                  ...
# 30883                                           0.055834
# 30884                                           0.039216
# 30885                                           0.063764
# 30886                                           0.066732
# 30887                                           0.082667
#
#        Rate 25 and Over w/ Some college, 1 or more years  \
# 0                                               0.116320
# 1                                               0.085659
# 2                                               0.114752
# 3                                               0.052037
# 4                                               0.094709
# ...                                                  ...
# 30883                                           0.190408
# 30884                                           0.176471
# 30885                                           0.158631
# 30886                                           0.310108
# 30887                                           0.148800
#
#        Rate 25 and Over w/ Associate's degree  \
# 0                                    0.075013
# 1                                    0.123564
# 2                                    0.069149
# 3                                    0.053366
# 4                                    0.116938
# ...                                       ...
# 30883                                0.063708
# 30884                                0.098039
# 30885                                0.091757
# 30886                                0.052012
# 30887                                0.068800
#
#        Rate 25 and Over w/ Bachelor's degree  \
# 0                                   0.150448
# 1                                   0.134690
# 2                                   0.171792
# 3                                   0.068866
# 4                                   0.130349
# ...                                      ...
# 30883                               0.141016
# 30884                               0.093137
# 30885                               0.082426
# 30886                               0.065751
# 30887                               0.140267
#
#        Rate 25 and Over w/ Master's degree  \
# 0                                 0.018246
# 1                                 0.040823
# 2                                 0.041927
# 3                                 0.026572
# 4                                 0.039084
# ...                                    ...
# 30883                             0.085183
# 30884                             0.049020
# 30885                             0.048212
# 30886                             0.033366
# 30887                             0.058133
#
#        Rate 25 and Over w/ Professional school degree  \
# 0                                            0.001267
# 1                                            0.007333
# 2                                            0.008665
# 3                                            0.000000
# 4                                            0.002818
# ...                                               ...
# 30883                                        0.006442
# 30884                                        0.000000
# 30885                                        0.003110
# 30886                                        0.006869
# 30887                                        0.003733
#
#        Rate 25 and Over w/ Doctorate degree
# 0                                  0.006673
# 1                                  0.011382
# 2                                  0.008169
# 3                                  0.000000
# 4                                  0.003444
# ...                                     ...
# 30883                              0.008590
# 30884                              0.000000
# 30885                              0.000000
# 30886                              0.000000
# 30887                              0.004800
#
# [30888 rows x 19 columns]

# %%
model = tf.keras.models.load_model("housing_model.h5")
mean = pd.read_csv("mean_norm.csv")
mean
# Out:
#    bathroom_ct  bedroom_ct    home_sqft    Population  Median Age  \
# 0     2.215294    3.167414  1780.877902  37791.788711    37.14016
#
#    Household Income  Per Capita Income  Poverty Rate  Population 25 and Over  \
# 0      57504.766533       28233.510809      0.161099            24473.959488
#
#    Rate 25 and Over w/ less than 1st grade  ...  \
# 0                                 0.018247  ...
#
#    Rate 25 and Over w/ Some or Completed Middle School  \
# 0                                            0.02387
#
#    Rate 25 and Over w/ Some High School  \
# 0                              0.085176
#
#    Rate 25 and Over w/ Completed High School or Equivalent  \
# 0                                           0.262559
#
#    Rate 25 and Over w/ Some college, less than 1 year  \
# 0                                           0.076063
#
#    Rate 25 and Over w/ Some college, 1 or more years  \
# 0                                           0.163205
#
#    Rate 25 and Over w/ Associate's degree  \
# 0                                0.084619
#
#    Rate 25 and Over w/ Bachelor's degree  Rate 25 and Over w/ Master's degree  \
# 0                               0.165052                             0.066861
#
#    Rate 25 and Over w/ Professional school degree  \
# 0                                        0.015153
#
#    Rate 25 and Over w/ Doctorate degree
# 0                               0.00959
#
# [1 rows x 21 columns]

# %%
std = pd.read_csv("std_norm.csv")
std
# Out:
#    bathroom_ct  bedroom_ct   home_sqft    Population  Median Age  \
# 0     0.686077    0.931858  751.846606  17663.256625     7.73332
#
#    Household Income  Per Capita Income  Poverty Rate  Population 25 and Over  \
# 0      19390.231666       11467.627605      0.087245             10786.88509
#
#    Rate 25 and Over w/ less than 1st grade  ...  \
# 0                                 0.013552  ...
#
#    Rate 25 and Over w/ Some or Completed Middle School  \
# 0                                           0.022315
#
#    Rate 25 and Over w/ Some High School  \
# 0                              0.048191
#
#    Rate 25 and Over w/ Completed High School or Equivalent  \
# 0                                           0.078214
#
#    Rate 25 and Over w/ Some college, less than 1 year  \
# 0                                            0.02347
#
#    Rate 25 and Over w/ Some college, 1 or more years  \
# 0                                           0.032047
#
#    Rate 25 and Over w/ Associate's degree  \
# 0                                 0.02362
#
#    Rate 25 and Over w/ Bachelor's degree  Rate 25 and Over w/ Master's degree  \
# 0                               0.083961                             0.040185
#
#    Rate 25 and Over w/ Professional school degree  \
# 0                                        0.015757
#
#    Rate 25 and Over w/ Doctorate degree
# 0                              0.008434
#
# [1 rows x 21 columns]

# %%
input_df =pd.DataFrame({"bathroom_ct": [2],
                       "bedroom_ct": [3.0],
                       "home_sqft": [1666.0],
                       "zipcode": [85003.0]})
merged_df = input_df.merge(census_df, how="inner")
merged_df.drop("zipcode", axis=1, inplace=True)
merged_df
# Out:
#    bathroom_ct  bedroom_ct  home_sqft  Population  Median Age  \
# 0            2         3.0     1666.0      8419.0        39.5
#
#    Household Income  Per Capita Income  Poverty Rate  Population 25 and Over  \
# 0           42936.0            37766.0      0.196223                  6750.0
#
#    Rate 25 and Over w/ less than 1st grade  ...  \
# 0                                 0.021037  ...
#
#    Rate 25 and Over w/ Some or Completed Middle School  \
# 0                                           0.019704
#
#    Rate 25 and Over w/ Some High School  \
# 0                              0.082074
#
#    Rate 25 and Over w/ Completed High School or Equivalent  \
# 0                                           0.186222
#
#    Rate 25 and Over w/ Some college, less than 1 year  \
# 0                                            0.05037
#
#    Rate 25 and Over w/ Some college, 1 or more years  \
# 0                                           0.178815
#
#    Rate 25 and Over w/ Associate's degree  \
# 0                                0.045185
#
#    Rate 25 and Over w/ Bachelor's degree  Rate 25 and Over w/ Master's degree  \
# 0                               0.225037                             0.104444
#
#    Rate 25 and Over w/ Professional school degree  \
# 0                                        0.034222
#
#    Rate 25 and Over w/ Doctorate degree
# 0                              0.022667
#
# [1 rows x 21 columns]

# %%
norm_df = (merged_df - mean) / std
norm_df
# Out:
#    bathroom_ct  bedroom_ct  home_sqft  Population  Median Age  \
# 0    -0.313804   -0.179656  -0.152794   -1.662932    0.305152
#
#    Household Income  Per Capita Income  Poverty Rate  Population 25 and Over  \
# 0         -0.751346           0.831252      0.402583               -1.643103
#
#    Rate 25 and Over w/ less than 1st grade  ...  \
# 0                                  0.20588  ...
#
#    Rate 25 and Over w/ Some or Completed Middle School  \
# 0                                          -0.186705
#
#    Rate 25 and Over w/ Some High School  \
# 0                             -0.064364
#
#    Rate 25 and Over w/ Completed High School or Equivalent  \
# 0                                          -0.975998
#
#    Rate 25 and Over w/ Some college, less than 1 year  \
# 0                                          -1.094724
#
#    Rate 25 and Over w/ Some college, 1 or more years  \
# 0                                           0.487086
#
#    Rate 25 and Over w/ Associate's degree  \
# 0                               -1.669516
#
#    Rate 25 and Over w/ Bachelor's degree  Rate 25 and Over w/ Master's degree  \
# 0                               0.714444                             0.935256
#
#    Rate 25 and Over w/ Professional school degree  \
# 0                                         1.21026
#
#    Rate 25 and Over w/ Doctorate degree
# 0                                1.5505
#
# [1 rows x 21 columns]

# %%
model.predict(norm_df)
# Out:
# array([[381967.44]], dtype=float32)
